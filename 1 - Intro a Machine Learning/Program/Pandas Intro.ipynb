# %%
import pandas as pd

# %% [markdown]
# ### Arreglos

# %%
series = pd.Series( [5, 10, 15, 20, 25] )
print(series)
type(series)
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series(['p','l','a','t','z','i'])
print(cad)
type(cad)
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object
# pandas.core.series.Series

# %%
lst = ['Hola', 'mundo', 'robotico']
df = pd.DataFrame(lst)
print(df)
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  robotico

# %%
data = { 'Nombre': ['Juan', 'Ana', 'Jose', 'Arturo' ], #Se asigna con la estructura, Cabezera : Datos
        'Edad' : [25, 18, 23, 27], 
        'Pais': ['MX', 'CO', 'BR', 'MX'] }
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad Pais
# 0    Juan    25   MX
# 1     Ana    18   CO
# 2    Jose    23   BR
# 3  Arturo    27   MX

# %%
print(df[[ 'Nombre', 'Pais' ]])
# Out:
#    Nombre Pais
# 0    Juan   MX
# 1     Ana   CO
# 2    Jose   BR
# 3  Arturo   MX

# %% [markdown]
# ### Manipulacion de archivos

# %%
data = pd.read_csv('canciones-2018.csv')
data.head(5)
#df = pd.read_csv('nombre.csv', delimiter = ',' , decimal = '.' , encoding= 'utf-8')
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
artista = data.artists #Llamar un dato en particular
artista[5]
# Out:
# 'Post Malone'

# %%
info = data.iloc[15]  #Informacion completa del dato "15"
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
data.tail() # Ver el final del archivo
# Out:
#                        id                               name       artists  \
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
# ...

# %%
data.shape #100 Filas y 16 Columnas
# Out:
# (100, 16)

# %%
data.columns #Nombre de las columnas
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe()  #Informacion de la columna "Tempo"
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis = 0, ascending = False)  #Forma de ordenar basica
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...

# %% [markdown]
# ### Challenge

# %%
newdata = pd.read_csv('canciones-2018.csv')
subset = newdata[['name', 'tempo', 'duration_ms']]
subset.sort_values(by="tempo",axis=0,ascending=True)   #sort_index es solo para el id, lo que no es muy util
# Out:
#                              name    tempo  duration_ms
# 38                        changes   64.934     121887.0
# 1                            SAD!   75.023     166606.0
# 0                      God's Plan   77.169     198973.0
# 71                  Feel It Still   79.028     163253.0
# 78                       Criminal   79.997     232550.0
# ..                            ...      ...          ...
# 98    Dusk Till Dawn - Radio Edit  180.043     239000.0
# 17                              X  180.073     173628.0
# 81                       Stir Fry  181.967     190288.0
# 93                     This Is Me  191.702     234707.0
# 85  Coraz?n (feat. Nego do Borel)  198.075     184720.0
#
# [100 rows x 3 columns]
